# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/ML project/bpp_training_data (1).csv')
final_df=pd.read_csv('/content/drive/MyDrive/ML project/bpp_test.csv')

# %%
X=df.drop(['SalePrice','MachineID','saleDayOfYear'],axis=1)
Y=df[["SalePrice"]]
final_df_drop=final_df.drop(['MachineID','saleDayOfYear'],axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=23)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDRegressor
sgdr=SGDRegressor()
print(sgdr)
sgdr.fit(X, Y)
# Out:
# SGDRegressor()
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1507: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,
# SGDRegressor()

# %%
model.fit(X,Y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(random_state=23)

# %%
Y_pred=model.predict(final_df_drop)
Y_pred
# Out:
# array([73932.5 , 15629.  , 20818.75, ..., 23890.  , 57520.  , 30175.  ])

# %%
submit_values=pd.DataFrame(Y_pred)

# %%
submit_values.to_csv('/content/drive/MyDrive/ML project/submit_values.csv', index=False)

# %%
#from sklearn.metrics import r2_score
#r2_score(Y_test, Y_pred)
#from sklearn.metrics import mean_absolute_error
#mean_absolute_error(Y_test.values, Y_pred)
# Out:
# 4178.073267
